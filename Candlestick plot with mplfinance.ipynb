# %%
# !pip install mplfinance
# !pip install python-binance
# !pip install yfinance
# Out:
# ...
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip
# ...
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
import mplfinance as mpf
from binance.client import Client
import yfinance as yf

# %%
start = '2020-01-01'
end = '2023-12-20'

# %%
data = yf.download("ETH-USD",period='1d',start=start,end=end)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
data
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2020-01-01   129.630661   132.835358   129.198288   130.802002   130.802002
# 2020-01-02   130.820038   130.820038   126.954910   127.410179   127.410179
# 2020-01-03   127.411263   134.554016   126.490021   134.171707   134.171707
# 2020-01-04   134.168518   136.052719   133.040558   135.069366   135.069366
# 2020-01-05   135.072098   139.410202   135.045624   136.276779   136.276779
# ...                 ...          ...          ...          ...          ...
# 2023-12-15  2316.110352  2316.892822  2214.263184  2219.337402  2219.337402
# 2023-12-16  2220.415527  2260.809814  2213.550781  2226.926514  2226.926514
# 2023-12-17  2226.892578  2244.366455  2195.761719  2196.481201  2196.481201
# 2023-12-18  2195.341797  2222.019287  2120.127441  2217.273438  2217.273438
# 2023-12-19  2218.240967  2253.348877  2139.723389  2177.872559  2177.872559
#
#                  Volume
# Date
# ...

# %%
from binance.client import Client
client = Client()

# %%
data = client.get_historical_klines("ETHUSDT", Client.KLINE_INTERVAL_1DAY, start, end)

# %%
data
# Out:
# [[1577836800000,
#   '129.16000000',
#   '133.05000000',
#   '128.68000000',
#   '130.77000000',
#   '144770.52197000',
#   1577923199999,
#   '18952318.53206430',
#   75888,
#   '71847.93883000',
#   '9407940.16106830',
#   '0'],
#  [1577923200000,
#   '130.72000000',
#   '130.78000000',
#   '126.38000000',
#   '127.19000000',
#   '213757.05806000',
#   1578009599999,
#   '27486853.39482150',
#   96193,
#   '105830.56192000',
#   '13615064.56872850',
#   '0'],
#  [1578009600000,
#   '127.19000000',
#   '135.14000000',
#   '125.88000000',
#   '134.35000000',
#   '413055.18895000',
#   1578095999999,
#   '54139288.21657680',
#   162310,
#   '227899.25531000',
#   '29863547.62120130',
#   '0'],
#  [1578096000000,
#   '134.37000000',
#   '135.85000000',
#   '132.50000000',
#   '134.20000000',
#   '184276.17102000',
#   1578182399999,
#   '24641135.56895300',
#   95488,
#   '85809.67556000',
#   '11476955.59469460',
#   '0'],
#  [1578182400000,
#   '134.20000000',
#   '138.19000000',
# ...

# %%
ETH = pd.DataFrame(data, columns =['otime','open','high','low','close','volume','ctime',
                                'quote_vol','no_trade','taker_base_vol','taker_quote_vol','ignore'])

# %%
ETH
# Out:
#              otime           open           high            low  \
# 0    1577836800000   129.16000000   133.05000000   128.68000000
# 1    1577923200000   130.72000000   130.78000000   126.38000000
# 2    1578009600000   127.19000000   135.14000000   125.88000000
# 3    1578096000000   134.37000000   135.85000000   132.50000000
# 4    1578182400000   134.20000000   138.19000000   134.19000000
# ..             ...            ...            ...            ...
# 715  1639612800000  4019.54000000  4113.43000000  3942.11000000
# 716  1639699200000  3959.11000000  3994.10000000  3700.00000000
# 717  1639785600000  3875.43000000  3996.93000000  3767.01000000
# 718  1639872000000  3959.93000000  4032.43000000  3884.00000000
# 719  1639958400000  3924.14000000  3983.37000000  3753.00000000
#
#              close           volume          ctime            quote_vol  \
# 0     130.77000000  144770.52197000  1577923199999    18952318.53206430
# ...

# %%
ETH = ETH[['otime','open','high','low','close','volume']]
ETH['otime'] = pd.to_datetime(ETH['otime'],unit= 'ms')
ETH
# Out:
#           otime           open           high            low          close  \
# 0    2020-01-01   129.16000000   133.05000000   128.68000000   130.77000000
# 1    2020-01-02   130.72000000   130.78000000   126.38000000   127.19000000
# 2    2020-01-03   127.19000000   135.14000000   125.88000000   134.35000000
# 3    2020-01-04   134.37000000   135.85000000   132.50000000   134.20000000
# 4    2020-01-05   134.20000000   138.19000000   134.19000000   135.37000000
# ...         ...            ...            ...            ...            ...
# 1445 2023-12-16  2220.51000000  2263.40000000  2210.00000000  2228.96000000
# 1446 2023-12-17  2228.96000000  2248.68000000  2191.50000000  2196.52000000
# 1447 2023-12-18  2196.53000000  2224.00000000  2116.60000000  2219.43000000
# 1448 2023-12-19  2219.44000000  2255.00000000  2135.55000000  2177.91000000
# 1449 2023-12-20  2177.90000000  2266.00000000  2156.00000000  2202.17000000
#
#                volume
# 0     144770.52197000
# ...

# %%
#Set otime = index

ETH.set_index('otime')
# Out:
#                      open           high            low          close  \
# otime
# 2020-01-01   129.16000000   133.05000000   128.68000000   130.77000000
# 2020-01-02   130.72000000   130.78000000   126.38000000   127.19000000
# 2020-01-03   127.19000000   135.14000000   125.88000000   134.35000000
# 2020-01-04   134.37000000   135.85000000   132.50000000   134.20000000
# 2020-01-05   134.20000000   138.19000000   134.19000000   135.37000000
# ...                   ...            ...            ...            ...
# 2023-12-16  2220.51000000  2263.40000000  2210.00000000  2228.96000000
# 2023-12-17  2228.96000000  2248.68000000  2191.50000000  2196.52000000
# 2023-12-18  2196.53000000  2224.00000000  2116.60000000  2219.43000000
# 2023-12-19  2219.44000000  2255.00000000  2135.55000000  2177.91000000
# 2023-12-20  2177.90000000  2266.00000000  2156.00000000  2202.17000000
#
#                      volume
# otime
# 2020-01-01  144770.52197000
# 2020-01-02  213757.05806000
# ...

# %%
ETH
# Out:
#           otime           open           high            low          close  \
# 0    2020-01-01   129.16000000   133.05000000   128.68000000   130.77000000
# 1    2020-01-02   130.72000000   130.78000000   126.38000000   127.19000000
# 2    2020-01-03   127.19000000   135.14000000   125.88000000   134.35000000
# 3    2020-01-04   134.37000000   135.85000000   132.50000000   134.20000000
# 4    2020-01-05   134.20000000   138.19000000   134.19000000   135.37000000
# ...         ...            ...            ...            ...            ...
# 1445 2023-12-16  2220.51000000  2263.40000000  2210.00000000  2228.96000000
# 1446 2023-12-17  2228.96000000  2248.68000000  2191.50000000  2196.52000000
# 1447 2023-12-18  2196.53000000  2224.00000000  2116.60000000  2219.43000000
# 1448 2023-12-19  2219.44000000  2255.00000000  2135.55000000  2177.91000000
# 1449 2023-12-20  2177.90000000  2266.00000000  2156.00000000  2202.17000000
#
#                volume
# 0     144770.52197000
# ...

# %%
ETH = ETH.set_index('otime')

# %%
ETH = ETH.astype(float)

# %%
ETH
# Out:
#                open     high      low    close        volume
# otime
# 2020-01-01   129.16   133.05   128.68   130.77  144770.52197
# 2020-01-02   130.72   130.78   126.38   127.19  213757.05806
# 2020-01-03   127.19   135.14   125.88   134.35  413055.18895
# 2020-01-04   134.37   135.85   132.50   134.20  184276.17102
# 2020-01-05   134.20   138.19   134.19   135.37  254120.45343
# ...             ...      ...      ...      ...           ...
# 2023-12-16  2220.51  2263.40  2210.00  2228.96  199285.92300
# 2023-12-17  2228.96  2248.68  2191.50  2196.52  225925.76750
# 2023-12-18  2196.53  2224.00  2116.60  2219.43  364103.11810
# 2023-12-19  2219.44  2255.00  2135.55  2177.91  383551.40490
# 2023-12-20  2177.90  2266.00  2156.00  2202.17  416841.62720
#
# [1450 rows x 5 columns]

# %%
ETH.loc['2020-01':'2023-12']
# Out:
#                open     high      low    close        volume
# otime
# 2020-01-01   129.16   133.05   128.68   130.77  144770.52197
# 2020-01-02   130.72   130.78   126.38   127.19  213757.05806
# 2020-01-03   127.19   135.14   125.88   134.35  413055.18895
# 2020-01-04   134.37   135.85   132.50   134.20  184276.17102
# 2020-01-05   134.20   138.19   134.19   135.37  254120.45343
# ...             ...      ...      ...      ...           ...
# 2023-12-16  2220.51  2263.40  2210.00  2228.96  199285.92300
# 2023-12-17  2228.96  2248.68  2191.50  2196.52  225925.76750
# 2023-12-18  2196.53  2224.00  2116.60  2219.43  364103.11810
# 2023-12-19  2219.44  2255.00  2135.55  2177.91  383551.40490
# 2023-12-20  2177.90  2266.00  2156.00  2202.17  416841.62720
#
# [1450 rows x 5 columns]

# %%
mpf.plot(ETH.loc['2020-01':'2023-12'])
# Out:
# /Users/arm2/anaconda3/lib/python3.11/site-packages/mplfinance/_arg_validators.py:84: UserWarning:
#
# ...
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
# ...
#   warnings.warn('\n\n ================================================================= '+

# %%
mpf.plot(ETH['2023-08':'2023-12'], type='candle')

# %%
mpf.plot(ETH['2023-09':], type='candle')

# %%
mpf.plot(ETH['2023-07':], type='line')

# %%
mpf.plot(ETH['2020-06':'2023-12'], type='candle', volume=True)
# Out:
# /Users/arm2/anaconda3/lib/python3.11/site-packages/mplfinance/_arg_validators.py:84: UserWarning:
#
# ...
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
# ...
#   warnings.warn('\n\n ================================================================= '+

# %%
mpf.plot(ETH['2020-06':'2023-12'], type='candle', volume=True,figsize=(25,15))
# Out:
# /Users/arm2/anaconda3/lib/python3.11/site-packages/mplfinance/_arg_validators.py:84: UserWarning:
#
# ...
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
# ...
#   warnings.warn('\n\n ================================================================= '+

# %%
mpf.plot(ETH['2020-12':'2023-12'], hlines=dict(hlines=[2000,1000], colors=['r','g'], linestyle='--'), type='candle')
# Out:
# /Users/arm2/anaconda3/lib/python3.11/site-packages/mplfinance/_arg_validators.py:84: UserWarning:
#
# ...
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
# ...
#   warnings.warn('\n\n ================================================================= '+

# %%
mpf.plot(ETH['2020-12':'2023-12'], hlines=dict(hlines=[2000,1000], colors=['r','g'], linestyle='-'), type='candle')
# Out:
# /Users/arm2/anaconda3/lib/python3.11/site-packages/mplfinance/_arg_validators.py:84: UserWarning:
#
# ...
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
# ...
#   warnings.warn('\n\n ================================================================= '+

# %%
mpf.plot(ETH, type='candle', mav=(12,26,100))
# Out:
# /Users/arm2/anaconda3/lib/python3.11/site-packages/mplfinance/_arg_validators.py:84: UserWarning:
#
# ...
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
# ...
#   warnings.warn('\n\n ================================================================= '+

# %%
mpf.plot(ETH[:'2023-12'], type='candle', volume=True, mav=(12,26),figsize=(20,10))
# Out:
# /Users/arm2/anaconda3/lib/python3.11/site-packages/mplfinance/_arg_validators.py:84: UserWarning:
#
# ...
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
# ...
#   warnings.warn('\n\n ================================================================= '+

# %%
mpf.plot(ETH, type='candle', volume=True, mav=(12,26,9), title='ETH Price',tight_layout=True, figratio=(30, 15))
# Out:
# /Users/arm2/anaconda3/lib/python3.11/site-packages/mplfinance/_arg_validators.py:84: UserWarning:
#
# ...
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
# ...
#   warnings.warn('\n\n ================================================================= '+

# %% [markdown]
# # make_addplot

# %%
ret = ETH['close'].pct_change(2)
ret
# Out:
# otime
# 2020-01-01         NaN
# 2020-01-02         NaN
# 2020-01-03    0.027376
# 2020-01-04    0.055114
# 2020-01-05    0.007592
#                 ...
# 2023-12-16   -0.037299
# 2023-12-17   -0.010799
# 2023-12-18   -0.004276
# 2023-12-19   -0.008472
# 2023-12-20   -0.007777
# Name: close, Length: 1450, dtype: float64

# %%
ETH.close
# Out:
# otime
# 2020-01-01     130.77
# 2020-01-02     127.19
# 2020-01-03     134.35
# 2020-01-04     134.20
# 2020-01-05     135.37
#                ...
# 2023-12-16    2228.96
# 2023-12-17    2196.52
# 2023-12-18    2219.43
# 2023-12-19    2177.91
# 2023-12-20    2202.17
# Name: close, Length: 1450, dtype: float64

# %%
ret_add = mpf.make_addplot(ret, color='b', ylabel='return')

# %%
mpf.plot(ETH, addplot=ret_add)
# Out:
# /Users/arm2/anaconda3/lib/python3.11/site-packages/mplfinance/_arg_validators.py:84: UserWarning:
#
# ...
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
# ...
#   warnings.warn('\n\n ================================================================= '+

# %%
ret_add = mpf.make_addplot(ret, color='k', panel=1,  ylabel='return')

# %%
mpf.plot(ETH, addplot=ret_add)
# Out:
# /Users/arm2/anaconda3/lib/python3.11/site-packages/mplfinance/_arg_validators.py:84: UserWarning:
#
# ...
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
# ...
#   warnings.warn('\n\n ================================================================= '+

# %%
mpf.plot(ETH, addplot=ret_add,volume=True)
# Out:
# /Users/arm2/anaconda3/lib/python3.11/site-packages/mplfinance/_arg_validators.py:84: UserWarning:
#
# ...
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
# ...
#   warnings.warn('\n\n ================================================================= '+

# %%
ret_add = mpf.make_addplot(ret, color='green', panel=2,  ylabel='return')
mpf.plot(ETH, addplot=ret_add,volume=True,mav=(12,26)) #mav = moving average
# Out:
# /Users/arm2/anaconda3/lib/python3.11/site-packages/mplfinance/_arg_validators.py:84: UserWarning:
#
# ...
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
# ...
#   warnings.warn('\n\n ================================================================= '+

# %%
ETH.close
# Out:
# otime
# 2020-01-01     130.77
# 2020-01-02     127.19
# 2020-01-03     134.35
# 2020-01-04     134.20
# 2020-01-05     135.37
#                ...
# 2023-12-16    2228.96
# 2023-12-17    2196.52
# 2023-12-18    2219.43
# 2023-12-19    2177.91
# 2023-12-20    2202.17
# Name: close, Length: 1450, dtype: float64

# %%
ETH.close.rolling(5).mean()
# Out:
# otime
# 2020-01-01         NaN
# 2020-01-02         NaN
# 2020-01-03         NaN
# 2020-01-04         NaN
# 2020-01-05     132.376
#                 ...
# 2023-12-16    2245.680
# 2023-12-17    2244.292
# 2023-12-18    2236.146
# 2023-12-19    2208.664
# 2023-12-20    2204.998
# Name: close, Length: 1450, dtype: float64

# %%
ETH.close.ewm(3).mean()
# Out:
# otime
# 2020-01-01     130.770000
# 2020-01-02     128.724286
# 2020-01-03     131.157027
# 2020-01-04     132.269886
# 2020-01-05     133.286056
#                  ...
# 2023-12-16    2253.423260
# 2023-12-17    2239.197445
# 2023-12-18    2234.255584
# 2023-12-19    2220.169188
# 2023-12-20    2215.669391
# Name: close, Length: 1450, dtype: float64

# %%
ETH['EMA_5'] = ETH['close'].ewm(5,adjust=False,min_periods=5).mean()

# %%
ema_plot = mpf.make_addplot(ETH['EMA_5'], ylabel='ema_5')

# %%
mpf.plot(ETH,addplot=ema_plot,style='charles')
# Out:
# /Users/arm2/anaconda3/lib/python3.11/site-packages/mplfinance/_arg_validators.py:84: UserWarning:
#
# ...
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
# ...
#   warnings.warn('\n\n ================================================================= '+

# %%
ETH['EMA_200'] = ETH['close'].ewm(200,adjust=False,min_periods=200).mean()
ema_plot = mpf.make_addplot(ETH['EMA_200'], ylabel='ema_200')
mpf.plot(ETH,addplot=ema_plot,style='charles')
# Out:
# /Users/arm2/anaconda3/lib/python3.11/site-packages/mplfinance/_arg_validators.py:84: UserWarning:
#
# ...
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
# ...
#   warnings.warn('\n\n ================================================================= '+

# %%
mpf.plot(ETH['2023-06':],type='candle',style='yahoo',mav=(5,12,21),volume=True, figsize=(15,5))
